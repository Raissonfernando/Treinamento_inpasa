# %%
import pandas as pd

# %%
bh_drd = pd.read_excel('C:/Users/raisson.vieira/desktop/Banco de Horas - Manutenção Dourados.xlsx')

# %%
bh_mtu = pd.read_excel('C:/Users/raisson.vieira/desktop/Banco de Horas - Nova Mutum.xlsx')

# %%
bh_snp = pd.read_excel('C:/Users/raisson.vieira/desktop/Banco de Horas - Sinop.xlsx')

# %%
matricula = pd.read_excel('C:/Users/raisson.vieira/desktop/sql452.xlsx')

# %%
df_drd = pd.merge(bh_drd, matricula, on='MATRICULA', how='left')

# %%
df_drd.columns
# Out:
# Index(['MES', 'ANO', 'MATRICULA', 'PERÍODO', 'NOME_x', 'SITUAÇÃO', 'CARGO_x',
#        'COD_SETOR', 'CODIGO CRITERIO', 'CRITERIO', 'CODIGO PLR', 'REALIZADO',
#        'Horas Efetivas Global', 'Horas Faltas Global', 'Horas Normais Global',
#        'Horas banco Global', 'Atrasos - qtde', 'Falta Injustificadas - qtde',
#        'Advertência - qtde', 'Suspensão - qtde', 'QTDE_FUNC_ATIVOS',
#        'QTDE_DEMITIDOS', 'QTDE_MES_ANT', 'QTDE_HORAS_NORMAIS',
#        'QTDE_HORAS_FALTA', 'QTDE_HORAS_BANCO', 'EMPRESA', 'ATIVO_SISTEMA',
#        'SITUACAO', 'LOGON', 'EMAIL_CORP', 'EMAIL_PESSOAL', 'NOME_y', 'DDD_CEL',
#        'TEL_CEL', 'DDD_RESID', 'TEL_RESID', 'DDD_COML', 'TEL_COML',
#        'GESTOR_IMEDIATO', 'CARGO_y', 'DEPARTAMENTO', 'DATA_ADMISSAO',
#        'DATA_DEMISSAO', 'DATA_INICIO_FERIAS', 'DATA_RET_FERIAS',
#        'DATA_AFASTAMENTO', 'COD_OBJ_CUSTO', 'DESC_OBJ_CUSTO'],
#       dtype='object')

# %%
df_drd_1 = df_drd[['MES', 'ANO', 'MATRICULA', 'NOME_x','CARGO_y', 'PERÍODO',
       'COD_SETOR', 'CODIGO CRITERIO', 'CRITERIO', 'CODIGO PLR', 'REALIZADO',
       'Horas Efetivas Global', 'Horas Faltas Global', 'Horas Normais Global',
       'Horas banco Global', 'QTDE_HORAS_NORMAIS',
       'QTDE_HORAS_FALTA', 'QTDE_HORAS_BANCO', 'EMPRESA', 
       'GESTOR_IMEDIATO',  'DEPARTAMENTO', 'COD_OBJ_CUSTO', 'DESC_OBJ_CUSTO']]

# %%
df_drd_1
# Out:
#      MES   ANO  MATRICULA                                 NOME_x  \
# 0      4  2024       5770  DOUGLAS CASTANHEDA DE ANDRADE SANCHES
# 1      1  2024       2877        BRUNA LORRAINE PEREIRA DA SILVA
# 2      2  2024       4596                    BRUNA NABOR FAVERAO
# 3      3  2024       5659               ARIEL RODRIGUES DE MOURA
# 4      3  2024       5696                LUCAS VASCONCELOS SALES
# ..   ...   ...        ...                                    ...
# 769    4  2024       7278                HIGOR TREVISAN DA SILVA
# 770    4  2024       7341                EDMAR DE SOUZA FERREIRA
# 771    4  2024       7362            RAFAEL ZOMERFELD DOS SANTOS
# 772    4  2024       7378                       KARLA RUTH OJEDA
# 773    4  2024       7383            RAPHAEL MUNIZ SIQUARA SILVA
#
#                                            CARGO_y  PERÍODO  COD_SETOR  \
# 0        ANALISTA ELETROMECANICO GERADOR DIESEL SR        1         80
# ...

# %%
df_drd_1.to_excel('C:/Users/raisson.vieira/desktop/BH - Manutenção Dourados.xlsx', index=False)

# %%
df_snp = pd.merge(bh_snp, matricula, on='MATRICULA', how='left')

# %%
df_mtu = pd.merge(bh_mtu, matricula, on='MATRICULA', how='left')

# %%
df_snp_1 = df_snp[['MES', 'ANO', 'MATRICULA', 'NOME_x','CARGO_y', 'PERÍODO',
       'COD_SETOR', 'CODIGO CRITERIO', 'CRITERIO', 'CODIGO PLR', 'REALIZADO',
       'Horas Efetivas Global', 'Horas Faltas Global', 'Horas Normais Global',
       'Horas banco Global', 'QTDE_HORAS_NORMAIS',
       'QTDE_HORAS_FALTA', 'QTDE_HORAS_BANCO', 'EMPRESA', 
       'GESTOR_IMEDIATO',  'DEPARTAMENTO', 'COD_OBJ_CUSTO', 'DESC_OBJ_CUSTO']]

# %%
df_mtu_1 = df_mtu[['MES', 'ANO', 'MATRICULA', 'NOME_x','CARGO_y', 'PERÍODO',
       'COD_SETOR', 'CODIGO CRITERIO', 'CRITERIO', 'CODIGO PLR', 'REALIZADO',
       'Horas Efetivas Global', 'Horas Faltas Global', 'Horas Normais Global',
       'Horas banco Global', 'QTDE_HORAS_NORMAIS',
       'QTDE_HORAS_FALTA', 'QTDE_HORAS_BANCO', 'EMPRESA', 
       'GESTOR_IMEDIATO',  'DEPARTAMENTO', 'COD_OBJ_CUSTO', 'DESC_OBJ_CUSTO']]

# %%
df_snp_1.to_excel('C:/Users/raisson.vieira/desktop/BH - Manutenção Sinop.xlsx', index=False)

# %%
df_mtu_1.to_excel('C:/Users/raisson.vieira/desktop/BH - Manutenção Mutum.xlsx', index=False)
